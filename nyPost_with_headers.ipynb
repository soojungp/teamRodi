# %% [markdown]
# <a href="https://colab.research.google.com/github/soojungp/teamRodi/blob/master/nyPost_with_headers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://github.com/codelucas/newspaper

# !pip install newspaper3k

from newspaper import Article

url = 'https://nypost.com/2021/04/09/'

article = Article(url)
article.download()
article.parse()
print(article.text)
# Out:
# ...
# Palace asks public not to lay flowers for Prince Philip due to COVID Buckingham Palace has asked the public to refrain from dropping off flowers in tribute to the late Prince Philip outside its gates because of pandemic restrictions. Dozens of floral displays...
#
# YouTube pulls video of DeSantis, scientists for saying kids don't need masks YouTube has yanked a video of Florida Gov. Ron DeSantis and a handful of medical experts discussing the COVID-19 pandemic because they questioned whether or not kids should wear masks,...
#
# Chilean scientists unearth skunk that walked among dinosaurs SANTIAGO – A fossil of a skunk-like mammal that lived during the age of dinosaurs has been discovered in Chilean Patagonia, adding further proof to recent evidence that mammals roamed...
#
# ...
